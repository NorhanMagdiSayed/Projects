# %%
# !nvidia-smi     #check access to GPU
# Out:
# Fri Oct  6 19:56:28 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip "/content/drive/MyDrive/grad project/dataset/TDD-Net/archive.zip" -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_04_1_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_04_2_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_04_3_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_04_4_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_05_1_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_05_2_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_05_3_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_05_4_600.txt
#   inflating: /content/pcb-defect-dataset/train/labels/rotation_270_light_09_mouse_bite_05_5_600.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.4/617.4 kB 7.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/pcb-defect-dataset/data.yaml epochs=50 imgsz=416 batch=16 name=pcb_1st_v8
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 80.1MB/s]
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/pcb_1st_v8/weights/best.pt data=/content/pcb-defect-dataset/data.yaml
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/pcb-defect-dataset/val/labels.cache... 802 images, 264 backgrounds, 0 corrupt: 100% 1066/1066 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 67/67 [00:12<00:00,  5.24it/s]
#                    all       1066       1595      0.974      0.973      0.983      0.549
#             mouse_bite       1066        280      0.982      0.964      0.981      0.549
#                   spur       1066        262      0.966      0.974       0.98      0.533
#           missing_hole       1066        229      0.992      0.996      0.995      0.604
#                  short       1066        327      0.981      0.962      0.981      0.553
#           open_circuit       1066        259       0.98      0.967      0.977      0.514
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/pcb_1st_v83/weights/best.pt conf=0.25 source=/content/dataset-pcb/images/val/04_short_17.jpg
# Out:
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients
#
# image 1/1 /content/dataset-pcb/images/val/04_short_17.jpg: 352x416 3 shorts, 105.7ms
# Speed: 2.4ms preprocess, 105.7ms inference, 3.5ms postprocess per image at shape (1, 3, 352, 416)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo export model=/content/runs/detect/pcb_1st_v83/weights/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.0.187 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11127906 parameters, 0 gradients
#
# PyTorch: starting from '/content/runs/detect/pcb_1st_v83/weights/best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 10, 3549) (21.4 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 56.3 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.6s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ...

# %%
# !yolo benchmark model=/content/runs/detect/pcb_1st_v8/weights/best.pt data=//content/pcb-defect-dataset/data.yaml imgsz=416 half=False device=cpu
# Out:
# image 1/1 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 416x320 (no detections), 120.8ms
# Speed: 1.9ms preprocess, 120.8ms inference, 0.6ms postprocess per image at shape (1, 3, 416, 320)
# val: Scanning /content/pcb-defect-dataset/val/labels.cache... 802 images, 264 backgrounds, 0 corrupt: 100% 1066/1066 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1066/1066 [02:13<00:00,  7.99it/s]
#                    all       1066       1595      0.974      0.973      0.983      0.549
# Speed: 1.0ms preprocess, 113.2ms inference, 0.0ms loss, 0.7ms postprocess per image
#
# PyTorch: starting from '/content/runs/detect/pcb_1st_v8/weights/best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 10, 3549) (5.9 MB)
#
# TorchScript: starting export with torch 2.0.1+cu118...
# TorchScript: export success ✅ 1.4s, saved as '/content/runs/detect/pcb_1st_v8/weights/best.torchscript' (11.8 MB)
#
# ...

# %%
# !zip -r "/content/drive/MyDrive/grad project/v8n-tdd.zip" /content/runs/detect/pcb_1st_v8
# Out:
#   adding: content/runs/detect/pcb_1st_v8/ (stored 0%)
#   adding: content/runs/detect/pcb_1st_v8/val_batch2_pred.jpg (deflated 10%)
#   adding: content/runs/detect/pcb_1st_v8/F1_curve.png (deflated 10%)
#   adding: content/runs/detect/pcb_1st_v8/events.out.tfevents.1696622418.80535d03774f.1616.0 (deflated 74%)
#   adding: content/runs/detect/pcb_1st_v8/val_batch0_labels.jpg (deflated 10%)
#   adding: content/runs/detect/pcb_1st_v8/train_batch21362.jpg (deflated 10%)
#   adding: content/runs/detect/pcb_1st_v8/weights/ (stored 0%)
#   adding: content/runs/detect/pcb_1st_v8/weights/best.mlpackage/ (stored 0%)
#   adding: content/runs/detect/pcb_1st_v8/weights/best.mlpackage/Data/ (stored 0%)
#   adding: content/runs/detect/pcb_1st_v8/weights/best.mlpackage/Data/com.apple.CoreML/ (stored 0%)
#   adding: content/runs/detect/pcb_1st_v8/weights/best.mlpackage/Data/com.apple.CoreML/weights/ (stored 0%)
# ...

# %%
# !zip -r "/content/drive/MyDrive/grad project/val-v8n.zip" /content/runs/detect/val
# Out:
#   adding: content/runs/detect/val/ (stored 0%)
#   adding: content/runs/detect/val/val_batch2_pred.jpg (deflated 12%)
#   adding: content/runs/detect/val/F1_curve.png (deflated 9%)
#   adding: content/runs/detect/val/val_batch0_labels.jpg (deflated 10%)
#   adding: content/runs/detect/val/val_batch0_pred.jpg (deflated 10%)
#   adding: content/runs/detect/val/val_batch1_labels.jpg (deflated 9%)
#   adding: content/runs/detect/val/val_batch2_labels.jpg (deflated 13%)
#   adding: content/runs/detect/val/confusion_matrix_normalized.png (deflated 23%)
#   adding: content/runs/detect/val/confusion_matrix.png (deflated 25%)
#   adding: content/runs/detect/val/PR_curve.png (deflated 18%)
#   adding: content/runs/detect/val/P_curve.png (deflated 15%)
#   adding: content/runs/detect/val/R_curve.png (deflated 10%)
#   adding: content/runs/detect/val/val_batch1_pred.jpg (deflated 9%)
